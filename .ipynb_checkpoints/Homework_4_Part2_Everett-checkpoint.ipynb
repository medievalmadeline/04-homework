# %% [markdown]
# # Last FM API (Music)
#
# Spotify's API is dead to us, so we're using Last.fm's - it's still music, just not as nice of an API.
#
# 1. Create an account at https://www.last.fm/api/
# 2. Create an "application" to get a key: https://www.last.fm/api/account/create
#     - It isn't a real application, it's just your project
#     - Name/description doesn't matter, ignore callback key and callback url
# 3. And save the API key that shows up on the next screen
#
# You can find documentation at https://www.last.fm/api/
#
# The domain for the API is `http://ws.audioscrobbler.com`, so all of your endpoints will be connected to that. To test your API key, check the following URL in your browser: `http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=cher&api_key=XXXXXXXXXXXXXXXXXXXX&format=json` (change the `XXXXXX` to be your API key, of course!).
#
# > Last.fm used to be called **AudioScrobbler**, which is why its URLs don't have "last.fm" in them.
# > While we're asking about URLs, notice that the API endpoints have a lot of `?` and `&` in them - these are key/value pairs, kind of like dictionaries, but for URLs instead of Python.

# %% [markdown]
# # FIRST: SETUP

# %% [markdown]
# ## 1) Import the libraries/packages you might need
#
# We need a library to read in the data for us! We don't like `urllib2`, so it must be something cooler and better.

# %%
# Import what you need here
import requests
from dotenv import load_dotenv
import os 
load_dotenv()

api_key = os.getenv('api_key')

# %% [markdown]
# ## 2) Save your API key
#
# Write your API key here so you don't forget it - it's the "api key" one, not the "shared secret" one

# %% [markdown]
# ## 3) The death of an API
#
# I used to have some code here that allowed you to display images, but _the images don't work any more._ Let this be an important lesson: when you depend on external services, they can die at any time.

# %% [markdown]
# # NOW: YOUR ASSIGNMENT

# %% [markdown]
# ## 1) Search for and print a list of 50 musicians with `lil` in their name, along with the number of listeners they have
#
# There are a lot of musicians with "Lil" in their name - it used to be all Lil Wayne and Lil Kim, but we live in a new world now!
#
# - *Tip: Remember, the domain for the API is `http://ws.audioscrobbler.com`*
# - *Tip: Make sure you ask the API for 50 musicians! This involves adding another parameter to the URL - notice they all have a `&` before them. [Read the documentation](http://www.last.fm/api/show/artist.search) to find the parameter's name.*
# - *Tip: When you are looking at any piece of data - is it a dictionary? Look at the keys! Is it a list? Look at the first element!*
# - *Tip: LOOK AT THE KEYS. and then the other keys and the other keys and the other keys. It's an ugly series of dictionaries!*

# %%
url = f'http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=lil&api_key={api_key}&format=json&limit=50'
response = requests.get(url)
data = response.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 url = f'http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=lil&api_key={api_key}&format=json&limit=50'
#       2 response = requests.get(url)
#       3 data = response.json()
#
# NameError: name 'api_key' is not defined

# %%
for artist in data['results']['artistmatches']['artist']:
    name = artist['name']
    listeners = artist['listeners']
    print(f"{name}: {listeners} listeners")
# Out:
# LIL UZI VERT: 1432972 listeners
# LIL PEEP: 1122888 listeners
# Lil Nas X: 1738804 listeners
# Lil Baby: 878998 listeners
# Lily Allen: 2677506 listeners
# Lil Yachty: 955941 listeners
# Lil' Wayne: 3380009 listeners
# Lil Tecca: 725149 listeners
# Lil Wayne: 1025962 listeners
# Lil Durk: 576889 listeners
# lil tjay: 574322 listeners
# lil skies: 489855 listeners
# Lil Darkie: 322665 listeners
# Lil Ugly Mane: 259090 listeners
# lil Mosey: 590781 listeners
# Lil B: 387419 listeners
# LIL PUMP: 501024 listeners
# LIL TRACY: 207899 listeners
# Lil Keed: 239490 listeners
# Lil Dicky: 459722 listeners
# Lil' Kim: 623047 listeners
# Lil Xan: 323194 listeners
# Lil Shine: 49099 listeners
# Lil Loaded: 156874 listeners
# LIL GNAR: 242650 listeners
# lilbubblegum: 145100 listeners
# lil mabu: 158590 listeners
# Lilypichu: 94807 listeners
# Lilly Wood & The Prick: 437919 listeners
# LIL DUSTY G: 133544 listeners
# Lil Jon & The East Side Boyz: 669190 listeners
# Lily Chou-Chou: 117918 listeners
# Lil Revive: 46504 listeners
# Lil Jon: 697717 listeners
# Lilac: 260522 listeners
# Lil Eazzyy: 175034 listeners
# Fenne Lily: 247484 listeners
# LIL BO WEEP: 94439 listeners
# Lil Aaron: 142503 listeners
# Lil Kleine: 96412 listeners
# Lil Gotit: 81229 listeners
# Lily James: 155843 listeners
# Lil Candy Paint: 125395 listeners
# Lil Boodang: 120428 listeners
# Lil Mariko: 98009 listeners
# Lilly Wood and The Prick: 197768 listeners
# Lila Downs: 193505 listeners
# Lil Lotus: 69772 listeners
# Lil God Dan: 77264 listeners
# The Tiger Lillies: 125699 listeners

# %%
# Out:
# dict_keys(['artist'])

# %%
# Out:
# LIL UZI VERT
# LIL PEEP
# Lil Nas X
# Lil Baby
# Lily Allen
# Lil Yachty
# Lil' Wayne
# Lil Tecca
# Lil Wayne
# Lil Durk
# lil tjay
# lil skies
# Lil Darkie
# Lil Ugly Mane
# lil Mosey
# Lil B
# LIL PUMP
# LIL TRACY
# Lil Keed
# Lil Dicky
# Lil' Kim
# Lil Xan
# Lil Shine
# Lil Loaded
# LIL GNAR
# lilbubblegum
# lil mabu
# Lilypichu
# Lilly Wood & The Prick
# LIL DUSTY G
# Lil Jon & The East Side Boyz
# Lily Chou-Chou
# Lil Revive
# Lil Jon
# Lilac
# Lil Eazzyy
# Fenne Lily
# LIL BO WEEP
# Lil Aaron
# Lil Kleine
# Lil Gotit
# Lily James
# Lil Candy Paint
# Lil Boodang
# Lil Mariko
# Lilly Wood and The Prick
# Lila Downs
# Lil Lotus
# Lil God Dan
# The Tiger Lillies

# %%
# Out:
# {'results': {'opensearch:Query': {'#text': '',
#    'role': 'request',
#    'searchTerms': 'lil',
#    'startPage': '1'},
#   'opensearch:totalResults': '604719',
#   'opensearch:startIndex': '0',
#   'opensearch:itemsPerPage': '50',
#   'artistmatches': {'artist': [{'name': 'LIL UZI VERT',
#      'listeners': '1432972',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/LIL+UZI+VERT',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'LIL PEEP',
#      'listeners': '1122888',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/LIL+PEEP',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Nas X',
#      'listeners': '1738804',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Nas+X',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Baby',
#      'listeners': '878998',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Baby',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lily Allen',
#      'listeners': '2677506',
#      'mbid': '6e0c7c0e-cba5-4c2c-a652-38f71ef5785d',
#      'url': 'https://www.last.fm/music/Lily+Allen',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Yachty',
#      'listeners': '955941',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Yachty',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': "Lil' Wayne",
#      'listeners': '3380009',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil%27+Wayne',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Tecca',
#      'listeners': '725149',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Tecca',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Wayne',
#      'listeners': '1025962',
#      'mbid': 'ac9a487a-d9d2-4f27-bb23-0f4686488345',
#      'url': 'https://www.last.fm/music/Lil+Wayne',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Durk',
#      'listeners': '576889',
#      'mbid': 'c9cd225b-4883-428e-82c2-73e0b6282fb6',
#      'url': 'https://www.last.fm/music/Lil+Durk',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'lil tjay',
#      'listeners': '574322',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/lil+tjay',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'lil skies',
#      'listeners': '489855',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/lil+skies',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Darkie',
#      'listeners': '322665',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Darkie',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Ugly Mane',
#      'listeners': '259090',
#      'mbid': '5f1adfe1-4d07-4141-b181-79e5d379d539',
#      'url': 'https://www.last.fm/music/Lil+Ugly+Mane',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'lil Mosey',
#      'listeners': '590781',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/lil+Mosey',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil B',
#      'listeners': '387419',
#      'mbid': '1550f952-c91b-40d7-9b4d-d26a259ee932',
#      'url': 'https://www.last.fm/music/Lil+B',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'LIL PUMP',
#      'listeners': '501024',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/LIL+PUMP',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'LIL TRACY',
#      'listeners': '207899',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/LIL+TRACY',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Keed',
#      'listeners': '239490',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Keed',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Dicky',
#      'listeners': '459722',
#      'mbid': '3268f062-6e76-480a-a384-e1dd2a276afb',
#      'url': 'https://www.last.fm/music/Lil+Dicky',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': "Lil' Kim",
#      'listeners': '623047',
#      'mbid': 'bc1b5c95-e6d6-46b5-957a-5e8908b02c1e',
#      'url': 'https://www.last.fm/music/Lil%27+Kim',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Xan',
#      'listeners': '323194',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Xan',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Shine',
#      'listeners': '49099',
#      'mbid': 'd4c7d574-c8f8-4c7e-ab45-fc612df367ca',
#      'url': 'https://www.last.fm/music/Lil+Shine',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Loaded',
#      'listeners': '156874',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Loaded',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'LIL GNAR',
#      'listeners': '242650',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/LIL+GNAR',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'lilbubblegum',
#      'listeners': '145100',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/lilbubblegum',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'lil mabu',
#      'listeners': '158590',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/lil+mabu',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lilypichu',
#      'listeners': '94807',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lilypichu',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lilly Wood & The Prick',
#      'listeners': '437919',
#      'mbid': '1b72331b-3a97-4981-a81c-eeee9c275d28',
#      'url': 'https://www.last.fm/music/Lilly+Wood+&+The+Prick',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'LIL DUSTY G',
#      'listeners': '133544',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/LIL+DUSTY+G',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Jon & The East Side Boyz',
#      'listeners': '669190',
#      'mbid': '243c6f61-d83b-4459-bebd-5899df0da111',
#      'url': 'https://www.last.fm/music/Lil+Jon+&+The+East+Side+Boyz',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lily Chou-Chou',
#      'listeners': '117918',
#      'mbid': '5652bb3e-f225-49de-9637-5aa1539b4a7c',
#      'url': 'https://www.last.fm/music/Lily+Chou-Chou',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Revive',
#      'listeners': '46504',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Revive',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Jon',
#      'listeners': '697717',
#      'mbid': 'a95384b1-6aec-468c-ae0d-8c6daf87c4c2',
#      'url': 'https://www.last.fm/music/Lil+Jon',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lilac',
#      'listeners': '260522',
#      'mbid': '1967c6ce-95a4-48f0-8ac7-abe637524aee',
#      'url': 'https://www.last.fm/music/Lilac',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Eazzyy',
#      'listeners': '175034',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Eazzyy',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Fenne Lily',
#      'listeners': '247484',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Fenne+Lily',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'LIL BO WEEP',
#      'listeners': '94439',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/LIL+BO+WEEP',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Aaron',
#      'listeners': '142503',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Aaron',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Kleine',
#      'listeners': '96412',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Kleine',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Gotit',
#      'listeners': '81229',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Gotit',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lily James',
#      'listeners': '155843',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lily+James',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Candy Paint',
#      'listeners': '125395',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Candy+Paint',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Boodang',
#      'listeners': '120428',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Boodang',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Mariko',
#      'listeners': '98009',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Mariko',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lilly Wood and The Prick',
#      'listeners': '197768',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lilly+Wood+and+The+Prick',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lila Downs',
#      'listeners': '193505',
#      'mbid': 'ad29ae1c-2eda-4071-9dc8-31910e7e546c',
#      'url': 'https://www.last.fm/music/Lila+Downs',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil Lotus',
#      'listeners': '69772',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+Lotus',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'Lil God Dan',
#      'listeners': '77264',
#      'mbid': '',
#      'url': 'https://www.last.fm/music/Lil+God+Dan',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]},
#     {'name': 'The Tiger Lillies',
#      'listeners': '125699',
#      'mbid': '3ad4f6ec-253f-4050-8849-ca26266edfb8',
#      'url': 'https://www.last.fm/music/The+Tiger+Lillies',
#      'streamable': '0',
#      'image': [{'#text': 'https://lastfm.freetls.fastly.net/i/u/34s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'small'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/64s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'medium'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/174s/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'large'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'extralarge'},
#       {'#text': 'https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png',
#        'size': 'mega'}]}]},
#   '@attr': {'for': 'lil'}}}

# %% [markdown]
# Your results should begin something like this:
#
# ```
# Lil' Wayne has 3086628 listeners
# Lily Allen has 2074266 listeners
# Lil B has 194116 listeners
# Lilly Wood & The Prick has 359886 listeners
# Lil Ugly Mane has 31955 listeners
# LIL UZI VERT has 88517 listeners
# ```

# %% [markdown]
# ## 2) How many listeners does your list have in total?
#
# The answer should be roughly **15,000,000**. If it's lower, make sure you have 50 artists instead of 30 artists.
#
# - *Tip: What's the data type of the `listeners` count? It's going to cause a problem!*
# - *Tip: If you were crazy you could use sum and a list comprehension. But you really don't have to!*

# %%
count = 0
for artist in data['results']['artistmatches']['artist']:
    listeners = int(artist['listeners'])
    count += listeners
print(count)
# Out:
# 24704844

# %% [markdown]
# ## 3) Show each artist's name and the URL to the extra-large image
#
# The images don't work any more, but we'll print their URLs out anyway.

# %% [markdown]
# Each artist **has a list of images of different sizes**. We're interested in the second-to-last one, where `size` is `extralarge`. Print their name and use `display_image` to display their extra-large image.
#
# - *Tip: The URL should look like this: `https://lastfm-img2.akamaized.net/i/u/300x300/0fc7d7a1812dc79e9925d80382cde594.png`*
# - *Tip: You can always assume it's the second to the last, or assume it's `extralarge`, or whatever you want to do to find it.*
# - *Tip: Make sure the URL is correct before you try to display it.*
#
# Your output should look something like
#
# ```
# Lil' Wayne
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ---
# LIL UZI VERT
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ---
# Lily Allen
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ---
# ```
#
# (but with more people, obviously)

# %%
for artist in data['results']['artistmatches']['artist']:
    print(artist['name'])
    print(artist['image'][-2]['#text'])
    print("------------------------------------")
# Out:
# LIL UZI VERT
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# LIL PEEP
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Nas X
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Baby
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lily Allen
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Yachty
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil' Wayne
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Tecca
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Wayne
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Durk
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# lil tjay
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# lil skies
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Darkie
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Ugly Mane
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# lil Mosey
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil B
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# LIL PUMP
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# LIL TRACY
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Keed
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Dicky
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil' Kim
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Xan
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Shine
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Loaded
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# LIL GNAR
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# lilbubblegum
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# lil mabu
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lilypichu
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lilly Wood & The Prick
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# LIL DUSTY G
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Jon & The East Side Boyz
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lily Chou-Chou
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Revive
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Jon
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lilac
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Eazzyy
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Fenne Lily
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# LIL BO WEEP
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Aaron
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Kleine
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Gotit
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lily James
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Candy Paint
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Boodang
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Mariko
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lilly Wood and The Prick
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lila Downs
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil Lotus
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# Lil God Dan
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------
# The Tiger Lillies
# https://lastfm.freetls.fastly.net/i/u/300x300/2a96cbd8b46e442fc41c2b86b821562f.png
# ------------------------------------

# %% [markdown]
# ## 4) Find Lil Jon's `mbid` (or anyone else's!).
#
# Oftentimes in an API, you can do a few things: you can **search** for items, and you can **see more information** about items. To find more information about the item, you need to use their **unique id**. In this dataset, it's called an `mbid` (MusicBrainz, I think - another company associated with last.fm!).
#
# Go through the artists and print their **name and mbid**. Find Lil Jon's `mbid`. I *wanted* Lil Uzi Vert's, but for some reason it isn't there. Then I wanted us to look at Lily Allen's, but I just couldn't bring myself to do that. If you'd rather do someone else, go for it.

# %%
for artist in data['results']['artistmatches']['artist']:
    print(artist['name'])
    print(artist['mbid'])
    print("--------------------------------------------------")
# Out:
# LIL UZI VERT
#
# --------------------------------------------------
# LIL PEEP
#
# --------------------------------------------------
# Lil Nas X
#
# --------------------------------------------------
# Lil Baby
#
# --------------------------------------------------
# Lily Allen
# 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# --------------------------------------------------
# Lil Yachty
#
# --------------------------------------------------
# Lil' Wayne
#
# --------------------------------------------------
# Lil Tecca
#
# --------------------------------------------------
# Lil Wayne
# ac9a487a-d9d2-4f27-bb23-0f4686488345
# --------------------------------------------------
# Lil Durk
# c9cd225b-4883-428e-82c2-73e0b6282fb6
# --------------------------------------------------
# lil tjay
#
# --------------------------------------------------
# lil skies
#
# --------------------------------------------------
# Lil Darkie
#
# --------------------------------------------------
# Lil Ugly Mane
# 5f1adfe1-4d07-4141-b181-79e5d379d539
# --------------------------------------------------
# lil Mosey
#
# --------------------------------------------------
# Lil B
# 1550f952-c91b-40d7-9b4d-d26a259ee932
# --------------------------------------------------
# LIL PUMP
#
# --------------------------------------------------
# LIL TRACY
#
# --------------------------------------------------
# Lil Keed
#
# --------------------------------------------------
# Lil Dicky
# 3268f062-6e76-480a-a384-e1dd2a276afb
# --------------------------------------------------
# Lil' Kim
# bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# --------------------------------------------------
# Lil Xan
#
# --------------------------------------------------
# Lil Shine
# d4c7d574-c8f8-4c7e-ab45-fc612df367ca
# --------------------------------------------------
# Lil Loaded
#
# --------------------------------------------------
# LIL GNAR
#
# --------------------------------------------------
# lilbubblegum
#
# --------------------------------------------------
# lil mabu
#
# --------------------------------------------------
# Lilypichu
#
# --------------------------------------------------
# Lilly Wood & The Prick
# 1b72331b-3a97-4981-a81c-eeee9c275d28
# --------------------------------------------------
# LIL DUSTY G
#
# --------------------------------------------------
# Lil Jon & The East Side Boyz
# 243c6f61-d83b-4459-bebd-5899df0da111
# --------------------------------------------------
# Lily Chou-Chou
# 5652bb3e-f225-49de-9637-5aa1539b4a7c
# --------------------------------------------------
# Lil Revive
#
# --------------------------------------------------
# Lil Jon
# a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# --------------------------------------------------
# Lilac
# 1967c6ce-95a4-48f0-8ac7-abe637524aee
# --------------------------------------------------
# Lil Eazzyy
#
# --------------------------------------------------
# Fenne Lily
#
# --------------------------------------------------
# LIL BO WEEP
#
# --------------------------------------------------
# Lil Aaron
#
# --------------------------------------------------
# Lil Kleine
#
# --------------------------------------------------
# Lil Gotit
#
# --------------------------------------------------
# Lily James
#
# --------------------------------------------------
# Lil Candy Paint
#
# --------------------------------------------------
# Lil Boodang
#
# --------------------------------------------------
# Lil Mariko
#
# --------------------------------------------------
# Lilly Wood and The Prick
#
# --------------------------------------------------
# Lila Downs
# ad29ae1c-2eda-4071-9dc8-31910e7e546c
# --------------------------------------------------
# Lil Lotus
#
# --------------------------------------------------
# Lil God Dan
#
# --------------------------------------------------
# The Tiger Lillies
# 3ad4f6ec-253f-4050-8849-ca26266edfb8
# --------------------------------------------------

# %% [markdown]
# ## 5) Find the artist's name and bio using their `mbid`.
#
# It can either be Lil Jon or whoever you selected above.
#
# If you look at the [last.fm documentation](http://www.last.fm/api/show/artist.getInfo), you can see how to use the artist's `mbid` to find more information about them. Print **every tag associated with your artist**.
#
# - *Tip: It's a new request to the API*
# - *Tip: Use the `mbid`, and make sure you delete the `&name=Cher` from the sample endpoint*
# - *Tip: If you use `print` for the bio it looks a little nicer than it would otherwise*

# %%
url = f'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=1967c6ce-95a4-48f0-8ac7-abe637524aee&api_key={api_key}&format=json'
response = requests.get(url)
lilac = response.json()

# %%
print(lilac['artist']['name'])
print(lilac['artist']['bio']['summary'])
# Out:
# Lilac
# 1. Producer and member of Helix Tears
# https://lil4c.bandcamp.com/
#
# 2. Noise rock band from Chicago, IL.
# https://lilacchicago.bandcamp.com/
#
# 3. Lilac is a Czech singer/songwriter. You can find more here: http://lilac.wz.cz. //
#
# 4. Also is an argentinean rock band, more information here: http://www.myspace.com/lilacsounds
#
# 5. Also is an belarusian rock band with female vocalist.
#
# 6. Dreamy shoegaze band from Stockholm Sweden https://lilac.bandcamp.com/ <a href="https://www.last.fm/music/Lilac">Read more on Last.fm</a>

# %% [markdown]
# ## 6) Print every tag of that artist

# %%
for tag in lilac['artist']['tags']['tag']:
    print(tag['name'])
# Out:
# seen live
# hardcore
# punk
# electronic
# trip-hop

# %% [markdown]
# # GETTING A LITTLE CRAZY
#
# So you know your original list of musicians? I want to get tag data for ALL OF THEM. How are we going to do that?
#
# ## 7) Find the mbids (again)
#
# If we have a musician with an mbid of `AAA-AAA-AAA`, we get their info from a url like `http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=AAA-AAA-AAA`.
#
# |artist|url|
# |---|---|
# |`AAA-AAA-AAA`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=AAA-AAA-AAA`|
# |`BBB-BBB-BBB`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=BBB-BBB-BBB`|
# |`CCC-CCC-CCC`|`http://ws.audioscrobbler.com/blahblah/?api_key=12345&mbid=CCC-CCC-CCC`|
#
# I guess we should start trying to get a list of all of the mbids.
#
# **Loop through your artists, and print out the `mbid` for each artist**
#
# - *Tip: You probably need to request your artist search result data again, because you probably saved over `data` with your other API request. Maybe call it `artist_data` this time?*
# - *Tip: If the artist does NOT have an `mbid`, don't print it.*

# %%
for artist in data['results']['artistmatches']['artist']:
    mbid = artist['mbid']
    if mbid != '':
        print(mbid)
# Out:
# 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# ac9a487a-d9d2-4f27-bb23-0f4686488345
# c9cd225b-4883-428e-82c2-73e0b6282fb6
# 5f1adfe1-4d07-4141-b181-79e5d379d539
# 1550f952-c91b-40d7-9b4d-d26a259ee932
# 3268f062-6e76-480a-a384-e1dd2a276afb
# bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# d4c7d574-c8f8-4c7e-ab45-fc612df367ca
# 1b72331b-3a97-4981-a81c-eeee9c275d28
# 243c6f61-d83b-4459-bebd-5899df0da111
# 5652bb3e-f225-49de-9637-5aa1539b4a7c
# a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# 1967c6ce-95a4-48f0-8ac7-abe637524aee
# ad29ae1c-2eda-4071-9dc8-31910e7e546c
# 3ad4f6ec-253f-4050-8849-ca26266edfb8

# %% [markdown]
# Your results should look something like
#
# ```
# 6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# 1550f952-c91b-40d7-9b4d-d26a259ee932
# 1b72331b-3a97-4981-a81c-eeee9c275d28
# 5f1adfe1-4d07-4141-b181-79e5d379d539
# a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# bc1b5c95-e6d6-46b5-957a-5e8908b02c1e
# 243c6f61-d83b-4459-bebd-5899df0da111
# ```

# %% [markdown]
# ## 8) Saving those mbids
#
# For those `mbid` values, instead of printing them out, save them to a new list of just mbid values. Call this list `mbids`.
#
# - *Tip: Use `.append` to add a single element onto a list*

# %%
mbids = []
for artist in data['results']['artistmatches']['artist']:
    mbid = artist['mbid']
    if mbid != '':
        mbids.append(mbid)
print(mbids)
# Out:
# ['6e0c7c0e-cba5-4c2c-a652-38f71ef5785d', 'ac9a487a-d9d2-4f27-bb23-0f4686488345', 'c9cd225b-4883-428e-82c2-73e0b6282fb6', '5f1adfe1-4d07-4141-b181-79e5d379d539', '1550f952-c91b-40d7-9b4d-d26a259ee932', '3268f062-6e76-480a-a384-e1dd2a276afb', 'bc1b5c95-e6d6-46b5-957a-5e8908b02c1e', 'd4c7d574-c8f8-4c7e-ab45-fc612df367ca', '1b72331b-3a97-4981-a81c-eeee9c275d28', '243c6f61-d83b-4459-bebd-5899df0da111', '5652bb3e-f225-49de-9637-5aa1539b4a7c', 'a95384b1-6aec-468c-ae0d-8c6daf87c4c2', '1967c6ce-95a4-48f0-8ac7-abe637524aee', 'ad29ae1c-2eda-4071-9dc8-31910e7e546c', '3ad4f6ec-253f-4050-8849-ca26266edfb8']

# %% [markdown]
# Your results should look something like
#
# ```['6e0c7c0e-cba5-4c2c-a652-38f71ef5785d',
#  '1550f952-c91b-40d7-9b4d-d26a259ee932',
#  '1b72331b-3a97-4981-a81c-eeee9c275d28',
#  '5f1adfe1-4d07-4141-b181-79e5d379d539',
#  'a95384b1-6aec-468c-ae0d-8c6daf87c4c2',
#  'bc1b5c95-e6d6-46b5-957a-5e8908b02c1e',
#  '243c6f61-d83b-4459-bebd-5899df0da111',
#  '8ba17cf6-bec2-4ae4-9820-b1cda47adc08',
#  'ad29ae1c-2eda-4071-9dc8-31910e7e546c',
#  '3268f062-6e76-480a-a384-e1dd2a276afb',
#  '3ad4f6ec-253f-4050-8849-ca26266edfb8',
#  '9b5ce0c1-1bc0-4ea2-a8d3-f5ee7af9eda8',
#  '981d39fc-bd00-4cc6-ac67-6410f8b89098',
#  'b89f4c50-72f5-48ce-b08c-a643b191b24f',
#  'bc21df5c-3d79-479b-b638-8ddb5ecea403',
#  'c9cd225b-4883-428e-82c2-73e0b6282fb6',
#  '9acaf734-b380-4c48-954c-a2cf1d7990a9',
#  'd4d5ae85-700c-4a55-8a39-7f923da07ef2',
#  '77fafce8-a32f-4d42-bdce-266bbf913cee',
#  '50ad1cde-1536-4268-a55f-e47a7b8280ab',
#  '9803d120-716d-45ba-9eb7-9a120813f908',
#  'b27560ea-2783-4a91-be45-9e8711917562',
#  '194e87c9-b3fe-4fbd-82a7-8c54b4dd4c76',
#  'fd90af91-ed07-4e85-8816-26c954fe5286',
#  '5652bb3e-f225-49de-9637-5aa1539b4a7c']```

# %% [markdown]
# ## 9) Printing our API urls
#
# To get tag data for each artist, you need to use those `mbid` values to access their artist page on the API. Loop through the mbids, displying the URL you'll need to access.
#
# - *Tip: You don't want to use a comma when printing, because commas add spaces into your text and URLs can't have that*
# - *Tip: Make sure your URL has `artist.getinfo` in it - if not, you're using the wrong endpoint.*

# %%
for mbid in mbids:
    mbid_url = f'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid={mbid}&api_key={api_key}&format=json')
# Out:
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=6e0c7c0e-cba5-4c2c-a652-38f71ef5785d&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=ac9a487a-d9d2-4f27-bb23-0f4686488345&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=c9cd225b-4883-428e-82c2-73e0b6282fb6&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=5f1adfe1-4d07-4141-b181-79e5d379d539&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=1550f952-c91b-40d7-9b4d-d26a259ee932&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=3268f062-6e76-480a-a384-e1dd2a276afb&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=bc1b5c95-e6d6-46b5-957a-5e8908b02c1e&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=d4c7d574-c8f8-4c7e-ab45-fc612df367ca&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=1b72331b-3a97-4981-a81c-eeee9c275d28&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=243c6f61-d83b-4459-bebd-5899df0da111&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=5652bb3e-f225-49de-9637-5aa1539b4a7c&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=a95384b1-6aec-468c-ae0d-8c6daf87c4c2&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=1967c6ce-95a4-48f0-8ac7-abe637524aee&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=ad29ae1c-2eda-4071-9dc8-31910e7e546c&api_key=b97fc7403f330ee330681116c264d4e8&format=json
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid=3ad4f6ec-253f-4050-8849-ca26266edfb8&api_key=b97fc7403f330ee330681116c264d4e8&format=json

# %% [markdown]
# Your results should look something like
#
# ```http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=6e0c7c0e-cba5-4c2c-a652-38f71ef5785d
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=1550f952-c91b-40d7-9b4d-d26a259ee932
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=1b72331b-3a97-4981-a81c-eeee9c275d28
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=5f1adfe1-4d07-4141-b181-79e5d379d539
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=a95384b1-6aec-468c-ae0d-8c6daf87c4c2
# http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&api_key=XXXXX&format=json&mbid=bc1b5c95-e6d6-46b5-957a-5e8908b02c1e```

# %% [markdown]
# ## OKAY HERE IS A LITTLE INFORMATION: Using our API urls
#
# This time instead of just *displaying* the URL, we're going to *request and process it*. **But first I'm going to teach you something.**
#
# When you're dealing with an API, you don't want to make a million requests, have bad code, and then need to do those million requests again. It's usually best to test your code with a few of the results first.
#
# So, if we have a list of numbers like this:

# %%
numbers = [4, 5, 6, 7]
numbers

# %% [markdown]
# You can actually say to Python, **give me the first two**, and it will only give you the first two.

# %%
numbers[:2]

# %% [markdown]
# The is **very convenient** with loopng with APIs, because instead of trying to use all FIFTY artists, you can just say "hey, please try this out with 2 of them" and you don't waste time.

# %% [markdown]
# ## 10) Using the first three `mbids`, request the API urls and print the artist's name.
#
# You built the URLs in the last question, now it's time to use them! Use `requests` etc to grab the URL and get out the artist's name.
#
# - *Tip: The code is the same as last time you got an artist's name from their info page, it's just going to be inside of a loop*
# - *Tip: USE `PRINT` TO SEE WHAT YOU ARE LOOKING AT!!!!!*

# %%
import requests

for mbid in mbids[:3]:
    url = f'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid={mbid}&api_key={api_key}&format=json'
    response = requests.get(url)
    data = response.json()
    print(data['artist']['name'])
# Out:
# Lily Allen
# Lil Wayne
# Lil Durk

# %% [markdown]
# ## 11) Using the first three `mbids`, request the API urls and print the artist's name and their tags
#
# - *Tip: The code is the same as last time you got an artist's name from their info page, it's just going to be inside of a loop*
# - *Tip: It's a for loop in a for loop!*

# %%
for mbid in mbids[:3]:
    url = f'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid={mbid}&api_key={api_key}&format=json'
    response = requests.get(url)
    data = response.json()
    name = data['artist']['name']
    print(f"{name}:")
    for tag in data['artist']['tags']['tag']:
        print("  ", tag['name'])
# Out:
# Lily Allen:
#    pop
#    female vocalists
#    british
#    britpop
#    singer-songwriter
# Lil Wayne:
#    rap
#    Hip-Hop
#    hip hop
#    Gangsta Rap
#    Dirty South
# Lil Durk:
#    rap
#    Hip-Hop
#    drill
#    trap
#    hip hop

# %% [markdown]
# ## 12) Using the first ten mbids, print the artist's name and whether they're a rapper
#
# Only print their name ONCE and only print whether they are hip hop or not ONCE.
#
# - *Tip: Rap tags include hip hop, swag, crunk, rap, dirty south, and probably a bunch of other stuff! You can include as many categories as you'd like.*
# - *Tip: You can use `2 in [1, 2, 3]` to find out if `2` is in the list of `[1, 2, 3]`.*
# - *Tip: Every time you look at a new artist, you can say they are NOT a rapper. And once you find out one of their tags is hip hop or rap, then you can note that they're a rapper. Then once you're done looking at their tags, then you can say HEY this is a rapper, or HEY this is not a rapper.*

# %%
 
# for tag in lilac['artist']['tags']['tag']:
#     print(tag['name'])



for mbid in mbids[:10]:
    url = f'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&mbid={mbid}&api_key={api_key}&format=json'
    response = requests.get(url)
    data = response.json()
    name = data['artist']['name']
    print(f'Artist: {name}')
    rap = ''
    for tag in data['artist']['tags']['tag']:
        tagname = tag['name']
        if tagname == 'Hip-Hop' or tagname == 'hip hop' or tagname == 'crunk' or tagname == 'rap' or tagname == 'dirty south' or tagname == 'Gangsta Rap' or tagname == 'cloud rap':
            rap = 'yes'
        else:
            rap = rap
    if rap == 'yes':
        print("yes! this is a rapper")
    else:
        print("no, this is not a rapper")
# Out:
# Artist: Lily Allen
# no, this is not a rapper
# Artist: Lil Wayne
# yes! this is a rapper
# Artist: Lil Durk
# yes! this is a rapper
# Artist: Lil Ugly Mane
# yes! this is a rapper
# Artist: Lil B
# yes! this is a rapper
# Artist: Lil Dicky
# yes! this is a rapper
# Artist: Lil' Kim
# yes! this is a rapper
# Artist: Lil Shine
# yes! this is a rapper
# Artist: Lilly Wood & The Prick
# no, this is not a rapper
# Artist: Lil Jon & The East Side Boyz
# yes! this is a rapper

# %% [markdown]
# Your results might look something like
#
# ```ARTIST: Lily Allen
# NO hip hop
# ARTIST: Lil B
# YES hip hop
# ARTIST: Lilly Wood & The Prick
# NO hip hop
# ARTIST: Lil Ugly Mane
# YES hip hop
# ARTIST: Lil Jon
# YES hip hop
# ARTIST: Lil' Kim
# YES hip hop
# ARTIST: Lil Jon & The East Side Boyz
# YES hip hop
# ```

# %% [markdown]
# ## 13) What percent of "lil" results are rappers?

# %%
url = f'http://ws.audioscrobbler.com/2.0/?method=artist.search&artist=lil&api_key={api_key}&format=json&limit=50'
response = requests.get(url)
data = response.json()

# %%
info_urls = []
for artist in data['results']['artistmatches']['artist']:
    name = artist['name']
    url = f'http://ws.audioscrobbler.com/2.0/?method=artist.getinfo&artist={name}&api_key={api_key}&format=json'
    info_urls.append(url)

# %%
count_rap = 0
count_no_rap = 0

for info_url in info_urls:
    url = info_url
    response = requests.get(url)
    data = response.json()
    name = data['artist']['name']
    rap = ''
    for tag in data['artist']['tags']['tag']:
        tagname = tag['name']
        if tagname == 'Hip-Hop' or tagname == 'hip hop' or tagname == 'crunk' or tagname == 'rap' or tagname == 'dirty south' or tagname == 'Gangsta Rap' or tagname == 'cloud rap':
            rap = 'yes'
        else:
            rap = rap
    if rap == 'yes':
        count_rap += 1
    else:
        count_no_rap += 1
print(f'Rappers: {count_rap} \nNot rappers: {count_no_rap}')
total = count_rap + count_no_rap
print(f'Total Artists: {total}')
percent_rappers = count_rap/total * 100
print(f'Percent Rappers: {percent_rappers}')
# Out:
# Rappers: 37
#  Not rappers: 13
# Total Artists: 50
# Percent Rappers: 74.0

# %% [markdown]
# ## 14) Seriously you are all-powerful now.
